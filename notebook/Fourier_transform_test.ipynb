# %%
import numpy as np
from scipy.fftpack import fft,ifft
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
data = pd.read_csv('./../run/tushare_data/hs300/20160130__20171231/hs300.csv',index_col='date')
close_value = data['close']

# %%
close_value.head(5)
print close_value.shape
# Out:
# (467,)

# %%
import numpy as np
close_value.plot()
x_time = np.arange(len(close_value.index))
plt.legend(loc='best')

# %%
close_fre = fft(close_value.values)
close_fre = abs(close_fre)
close_fre_1 = close_fre[range(int(len(x_time)/2))]
x_fre = np.arange(len(x_time))
x_fre_1 = x_fre[range(int(len(x_time)/2))]
print len(close_fre)
# Out:
# 467

# %%
plt.plot(x_fre,np.log10(close_fre))

# %%
plt.plot(x_fre_1,np.log10(close_fre_1))
